# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
def solution(nums):
    
    answer = 0
    
    for i in range(int(len(nums)/2)):
        b = list(set(nums))

        try:
            if b[i] in nums:
                answer += 1
        except:
            break

    return answer
