# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(a, b):

    one = []
    
    for index, value in enumerate(a):
        c = value * b[index]
        one.append(c)
        
    return sum(one)
