# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arr = [4, 3, 2, 1]
min(arr)
# Out:
# 1

# %%
arr.remove(min(arr))
arr
# Out:
# [4, 3, 2]

# %%
# arr=[10]
arr = [4, 3, 2, 1]
def solution(arr):
    if len(arr)==1:
        return [-1]
    else:
        arr.remove(min(arr))
        return arr
    
solution(arr)
# Out:
# [4, 3, 2]
