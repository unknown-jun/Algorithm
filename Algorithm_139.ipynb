# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(num):
    if num % 2:
        return "Odd"
    else:
        return "Even"

# %%
num = [3, 4]
answer = ["Odd", "Even"]
for i, z in zip(num, answer):
    if solution(i) == z:
        print("정답")
# Out:
# 정답
# 정답
