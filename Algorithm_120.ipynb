# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/70187490/125164965-d9978d80-e1cf-11eb-96bf-a02b488caab3.png)

# %%
def solution(arr):
    result = []
    result.append(arr[0])
    for i in range(1, len(arr)):
        if arr[i] != arr[i-1]:
            result.append(arr[i])
    return result
