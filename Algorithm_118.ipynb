# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/70187490/125164831-38a8d280-e1cf-11eb-99e9-efa8602ab331.png)

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/70187490/125164841-4a8a7580-e1cf-11eb-8476-c0554fbc10fe.png)

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/70187490/125164860-5f670900-e1cf-11eb-9ad3-05ff98875b6b.png)

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/70187490/125164877-6f7ee880-e1cf-11eb-8785-aeadba80baec.png)

# %%
def solution(n, arr1, arr2):

    answer = [''] * n

    binarys_1 = [ bin(i)[2:] for i in arr1 ]
    binarys_2 = [ bin(i)[2:] for i in arr2 ]

    def fill_0(binarys):
        cnt = 0
        for binary in binarys:
            if len(binary) < n:
                while len(binary) < n:
                    binary = '0'+str(binary)
                binarys[cnt] = binary
            cnt += 1

        return binarys

    def make_map(binarys):
        import re
        cnt = 0

        for binary in binarys:
            binarys[cnt] = re.sub('0', ' ', binary)
            binarys[cnt] = re.sub('1', '#', binarys[cnt])
            cnt+=1

        return binarys

    binarys_1 = fill_0(binarys_1)
    binarys_2 = fill_0(binarys_2)

    binarys_1 = make_map(binarys_1)
    binarys_2 = make_map(binarys_2)

    cnt = 0
    for binarys_list1,binarys_list2 in zip(binarys_1, binarys_2):
        for i, z in zip(binarys_list1,binarys_list2):
            if i == '#' or z == '#':
                answer[cnt] = answer[cnt]+'#'
            else:
                answer[cnt] = answer[cnt]+' '
        cnt += 1

    return answer
